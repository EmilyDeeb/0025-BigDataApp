# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyDeeb/0025-BSA/blob/main/W02_sql_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SQL Basics
#
# ## Introduction
#
# This notebook is a short introduction to SQL. It is based on the [DuckDB](https://duckdb.org/) database engine.
#
# ## Datasets
#
# The following datasets are used in this notebook. You don't need to download them, they can be accessed directly from the notebook.
#
# - [cities.csv](https://storage.googleapis.com/qm2/CASA0025/cities.csv)
# - [countries.csv](https://storage.googleapis.com/qm2/CASA0025/countries.csv)
#
# ## References
#
# - [W3Schools SQL Tutorial](https://www.w3schools.com/sql)
# - [DuckDB SQL Introduction](https://duckdb.org/docs/sql/introduction.html)

# %% [markdown]
# ## Installation
#
# Uncomment the following cell to install the required packages.

# %%
# %pip install duckdb duckdb-engine jupysql
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)
# Collecting duckdb-engine
#   Downloading duckdb_engine-0.17.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupysql
#   Downloading jupysql-0.11.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from duckdb-engine) (25.0)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /usr/local/lib/python3.12/dist-packages (from duckdb-engine) (2.0.45)
# Requirement already satisfied: prettytable>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from jupysql) (3.17.0)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.12/dist-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in /usr/local/lib/python3.12/dist-packages (from jupysql) (25.20.2)
# Collecting jupysql-plugin>=0.4.2 (from jupysql)
#   Downloading jupysql_plugin-0.4.5-py3-none-any.whl.metadata (7.8 kB)
# Collecting ploomber-core>=0.2.7 (from jupysql)
#   Downloading ploomber_core-0.2.27-py3-none-any.whl.metadata (532 bytes)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from ploomber-core>=0.2.7->jupysql) (6.0.3)
# Collecting posthog>=3.0 (from ploomber-core>=0.2.7->jupysql)
#   Downloading posthog-7.6.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.12.0->jupysql) (0.2.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->jupysql) (3.0.3)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2026.1.4)
# Downloading duckdb_engine-0.17.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 2.1 MB/s eta 0:00:00
# Downloading jupysql-0.11.1-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 3.5 MB/s eta 0:00:00
# Downloading jupysql_plugin-0.4.5-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 7.3 MB/s eta 0:00:00
# Downloading ploomber_core-0.2.27-py3-none-any.whl (22 kB)
# Downloading posthog-7.6.0-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 kB 12.8 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: backoff, posthog, duckdb-engine, ploomber-core, jupysql-plugin, jupysql
# Successfully installed backoff-2.2.1 duckdb-engine-0.17.0 jupysql-0.11.1 jupysql-plugin-0.4.5 ploomber-core-0.2.27 posthog-7.6.0

# %% [markdown]
# ## Library Import and Configuration

# %%
import duckdb #python code
import pandas as pd #py

# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql

# %% [markdown]
# Set configurations on jupysql to directly output data to Pandas and to simplify the output that is printed to the notebook.

# %%
# %config SqlMagic.autopandas = True # automatically convert SQL to panda df
# %config SqlMagic.feedback = False  # clean status updates
# %config SqlMagic.displaycon = False # hides connection details

# %% [markdown]
# ## Connecting to DuckDB
#
# Connect jupysql to DuckDB using a SQLAlchemy-style connection string. You may either connect to an in memory DuckDB, or a file backed db.

# %%
# %sql duckdb:///:memory:
# %sql duckdb:///path/to/file.db

# %% [markdown]
#  If your SQL query is one line only, you may use the `%sql` magic command. For multi-line SQL query, you may use the `%%sql` magic command.

# %% [markdown]
# ## Install extensions

# %% [markdown]
# Check available DuckDB extensions.

# %%
# %%sql
#
# SELECT * FROM duckdb_extensions();
# Out:
#       extension_name  loaded  installed install_path  \
# 0       autocomplete   False      False
# 1                aws   False      False
# 2              azure   False      False
# 3     core_functions    True       True   (BUILT-IN)
# 4              delta   False      False
# 5           ducklake   False      False
# 6          encodings   False      False
# 7              excel   False      False
# 8                fts   False      False
# 9             httpfs   False      False
# 10           iceberg   False      False
# 11               icu    True       True   (BUILT-IN)
# 12              inet   False      False
# 13          jemalloc    True       True   (BUILT-IN)
# 14              json    True       True   (BUILT-IN)
# 15        motherduck   False      False
# 16     mysql_scanner   False      False
# 17           parquet    True       True   (BUILT-IN)
# 18  postgres_scanner   False      False
# 19           spatial   False      False
# 20    sqlite_scanner   False      False
# 21             tpcds   False      False
# 22              tpch   False      False
# 23                ui   False      False
# 24               vss   False      False
#
#                                           description            aliases  \
# 0          Adds support for autocomplete in the shell                 []
# 1        Provides features that depend on the AWS SDK                 []
# 2   Adds a filesystem abstraction for Azure blob s...                 []
# 3                               Core function library                 []
# 4                         Adds support for Delta Lake                 []
# 5   Adds support for DuckLake, SQL as a Lakehouse ...                 []
# 6                      All unicode encodings to UTF-8                 []
# 7          Adds support for Excel-like format strings                 []
# 8           Adds support for Full-Text Search Indexes                 []
# 9   Adds support for reading and writing files ove...  [http, https, s3]
# 10                    Adds support for Apache Iceberg                 []
# 11  Adds support for time zones and collations usi...                 []
# 12  Adds support for IP-related data types and fun...                 []
# 13          Overwrites system allocator with JEMalloc                 []
# 14                   Adds support for JSON operations                 []
# 15     Enables motherduck integration with the system               [md]
# 16    Adds support for connecting to a MySQL database            [mysql]
# 17  Adds support for reading and writing parquet f...                 []
# 18  Adds support for connecting to a Postgres data...         [postgres]
# 19  Geospatial extension that adds support for wor...                 []
# 20  Adds support for reading and writing SQLite da...  [sqlite, sqlite3]
# 21      Adds TPC-DS data generation and query support                 []
# 22       Adds TPC-H data generation and query support                 []
# 23                           Adds local UI for DuckDB                 []
# 24  Adds indexing support to accelerate Vector Sim...                 []
#
#    extension_version       install_mode installed_from
# 0                         NOT_INSTALLED
# 1                         NOT_INSTALLED
# 2                         NOT_INSTALLED
# 3                     STATICALLY_LINKED
# 4                         NOT_INSTALLED
# 5                         NOT_INSTALLED
# 6                         NOT_INSTALLED
# 7                         NOT_INSTALLED
# 8                         NOT_INSTALLED
# 9                         NOT_INSTALLED
# 10                        NOT_INSTALLED
# 11                    STATICALLY_LINKED
# 12                        NOT_INSTALLED
# 13                    STATICALLY_LINKED
# 14                    STATICALLY_LINKED
# 15                        NOT_INSTALLED
# 16                        NOT_INSTALLED
# 17                    STATICALLY_LINKED
# 18                        NOT_INSTALLED
# 19                        NOT_INSTALLED
# 20                        NOT_INSTALLED
# 21                        NOT_INSTALLED
# 22                        NOT_INSTALLED
# 23                        NOT_INSTALLED
# 24                        NOT_INSTALLED

# %% [markdown]
# DuckDB's [httpfs extension](https://duckdb.org/docs/extensions/httpfs) allows parquet and csv files to be queried remotely over http. This is useful for querying large datasets without having to download them locally. Let's install the extension and load the extension.

# %%
# %%sql
#
# INSTALL httpfs;
# LOAD httpfs;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## Read CSV
#
# Use the `httpfs` extension to read the `cities.csv` file from the web.

# %%
# %%sql
#
# SELECT * FROM 'https://storage.googleapis.com/qm2/CASA0025/cities.csv';
# Out:
#         id            name country  latitude  longitude  population
# 0        1           Bombo     UGA   0.58330   32.53330       75000
# 1        2     Fort Portal     UGA   0.67100   30.27500       42670
# 2        3         Potenza     ITA  40.64200   15.79900       69060
# 3        4      Campobasso     ITA  41.56300   14.65600       50762
# 4        5           Aosta     ITA  45.73700    7.31500       34062
# ...    ...             ...     ...       ...        ...         ...
# 1244  1245  Rio de Janeiro     BRA -22.92502  -43.22502    11748000
# 1245  1246       Sao Paulo     BRA -23.55868  -46.62502    18845000
# 1246  1247          Sydney     AUS -33.92001  151.18518     4630000
# 1247  1248       Singapore     SGP   1.29303  103.85582     5183700
# 1248  1249       Hong Kong     CHN  22.30498  114.18501     7206000
#
# [1249 rows x 6 columns]

# %%
# %%sql
#
# SELECT * FROM 'https://storage.googleapis.com/qm2/CASA0025/countries.csv';
# Out:
#       id            Country Alpha2_code Alpha3_code  Numeric_code  Latitude  \
# 0      1        Afghanistan          AF         AFG             4   33.0000
# 1      2            Albania          AL         ALB             8   41.0000
# 2      3            Algeria          DZ         DZA            12   28.0000
# 3      4     American Samoa          AS         ASM            16  -14.3333
# 4      5            Andorra          AD         AND            20   42.5000
# ..   ...                ...         ...         ...           ...       ...
# 238  239  Wallis and Futuna          WF         WLF           876  -13.3000
# 239  240     Western Sahara          EH         ESH           732   24.5000
# 240  241              Yemen          YE         YEM           887   15.0000
# 241  242             Zambia          ZM         ZMB           894  -15.0000
# 242  243           Zimbabwe          ZW         ZWE           716  -20.0000
#
#      Longitude
# 0         65.0
# 1         20.0
# 2          3.0
# 3       -170.0
# 4          1.6
# ..         ...
# 238     -176.2
# 239      -13.0
# 240       48.0
# 241       30.0
# 242       30.0
#
# [243 rows x 7 columns]

# %% [markdown]
# ## Create Table
#
# Create a table named `cities` from the `cities.csv` file.

# %%
# %%sql
#
# CREATE TABLE cities AS SELECT * FROM 'https://storage.googleapis.com/qm2/CASA0025/cities.csv';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Create a table named `countries` from the `countries.csv` file.

# %%
# %%sql
#
# CREATE TABLE countries AS SELECT * FROM 'https://storage.googleapis.com/qm2/CASA0025/countries.csv';
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Display the table content in the database.

# %%
# %%sql
#
# FROM cities;
# Out:
#         id            name country  latitude  longitude  population
# 0        1           Bombo     UGA   0.58330   32.53330       75000
# 1        2     Fort Portal     UGA   0.67100   30.27500       42670
# 2        3         Potenza     ITA  40.64200   15.79900       69060
# 3        4      Campobasso     ITA  41.56300   14.65600       50762
# 4        5           Aosta     ITA  45.73700    7.31500       34062
# ...    ...             ...     ...       ...        ...         ...
# 1244  1245  Rio de Janeiro     BRA -22.92502  -43.22502    11748000
# 1245  1246       Sao Paulo     BRA -23.55868  -46.62502    18845000
# 1246  1247          Sydney     AUS -33.92001  151.18518     4630000
# 1247  1248       Singapore     SGP   1.29303  103.85582     5183700
# 1248  1249       Hong Kong     CHN  22.30498  114.18501     7206000
#
# [1249 rows x 6 columns]

# %%
# %%sql
#
# FROM countries;
# Out:
#       id            Country Alpha2_code Alpha3_code  Numeric_code  Latitude  \
# 0      1        Afghanistan          AF         AFG             4   33.0000
# 1      2            Albania          AL         ALB             8   41.0000
# 2      3            Algeria          DZ         DZA            12   28.0000
# 3      4     American Samoa          AS         ASM            16  -14.3333
# 4      5            Andorra          AD         AND            20   42.5000
# ..   ...                ...         ...         ...           ...       ...
# 238  239  Wallis and Futuna          WF         WLF           876  -13.3000
# 239  240     Western Sahara          EH         ESH           732   24.5000
# 240  241              Yemen          YE         YEM           887   15.0000
# 241  242             Zambia          ZM         ZMB           894  -15.0000
# 242  243           Zimbabwe          ZW         ZWE           716  -20.0000
#
#      Longitude
# 0         65.0
# 1         20.0
# 2          3.0
# 3       -170.0
# 4          1.6
# ..         ...
# 238     -176.2
# 239      -13.0
# 240       48.0
# 241       30.0
# 242       30.0
#
# [243 rows x 7 columns]

# %% [markdown]
# ## The SQL SELECT statement
#
# The `SELECT` statement is used to select data from a database. Use either `SELECT *` to select all columns, or `SELECT column1, column2, ...` to select specific columns.
#
# `SELECT * FROM cities` is the same as `FROM cities`.

# %%
# %%sql
#
# SELECT * FROM cities;
# Out:
#         id            name country  latitude  longitude  population
# 0        1           Bombo     UGA   0.58330   32.53330       75000
# 1        2     Fort Portal     UGA   0.67100   30.27500       42670
# 2        3         Potenza     ITA  40.64200   15.79900       69060
# 3        4      Campobasso     ITA  41.56300   14.65600       50762
# 4        5           Aosta     ITA  45.73700    7.31500       34062
# ...    ...             ...     ...       ...        ...         ...
# 1244  1245  Rio de Janeiro     BRA -22.92502  -43.22502    11748000
# 1245  1246       Sao Paulo     BRA -23.55868  -46.62502    18845000
# 1246  1247          Sydney     AUS -33.92001  151.18518     4630000
# 1247  1248       Singapore     SGP   1.29303  103.85582     5183700
# 1248  1249       Hong Kong     CHN  22.30498  114.18501     7206000
#
# [1249 rows x 6 columns]

# %% [markdown]
# To limit the number of rows returned, use the `LIMIT` keyword. For example, `SELECT * FROM cities LIMIT 10` will return only the first 10 rows.

# %%
# %%sql
#
# SELECT * FROM cities LIMIT 10;
# Out:
#    id              name country  latitude  longitude  population
# 0   1             Bombo     UGA   0.58330   32.53330       75000
# 1   2       Fort Portal     UGA   0.67100   30.27500       42670
# 2   3           Potenza     ITA  40.64200   15.79900       69060
# 3   4        Campobasso     ITA  41.56300   14.65600       50762
# 4   5             Aosta     ITA  45.73700    7.31500       34062
# 5   6         Mariehamn     ALD  60.09700   19.94900       10682
# 6   7          Ramallah     PSE  31.90294   35.20621       24599
# 7   8      Vatican City     VAT  41.90001   12.44781         832
# 8   9           Poitier     FRA  46.58329    0.33328       85960
# 9  10  Clermont-Ferrand     FRA  45.77998    3.08001      233050

# %% [markdown]
# Select a subset of columns from the `cities` table and display the first 10 rows.

# %%
# %%sql
#
# SELECT name, country FROM cities LIMIT 10;
# Out:
#                name country
# 0             Bombo     UGA
# 1       Fort Portal     UGA
# 2           Potenza     ITA
# 3        Campobasso     ITA
# 4             Aosta     ITA
# 5         Mariehamn     ALD
# 6          Ramallah     PSE
# 7      Vatican City     VAT
# 8           Poitier     FRA
# 9  Clermont-Ferrand     FRA

# %% [markdown]
# To select distinct values, use the `DISTINCT` keyword. For example, `SELECT DISTINCT country FROM cities` will return only the distinct values of the `country` column.

# %%
# %%sql
#
# SELECT DISTINCT country #no dupes
# FROM cities
# LIMIT 10;

# %% [markdown]
# To count the number of rows returned, use the `COUNT(*)` function. For example, `SELECT COUNT(*) FROM cities` will return the number of rows in the `cities` table.

# %%
# %%sql
#
# SELECT COUNT(*) # number of rows
# FROM cities;
# Out:
#    count_star()
# 0          1249

# %%
# %%sql
#
# SELECT COUNT(*) # number of rows
# FROM countries;
# Out:
#    count_star()
# 0           243

# %% [markdown]
# To count the number of distinct values, use the `COUNT(DISTINCT column)` function. For example, `SELECT COUNT(DISTINCT country) FROM cities` will return the number of distinct values in the `country` column.

# %%
# %%sql
#
# SELECT COUNT(DISTINCT country) # number rows without dupes
# FROM cities;
# Out:
#    count(DISTINCT country)
# 0                      200

# %% [markdown]
# To calculate the maximum value, use the `MAX(column)` function. For example, `SELECT MAX(population) FROM cities` will return the maximum value in the `population` column.

# %%
# %%sql
#
# SELECT MAX(population)
# FROM cities;
# Out:
#    max(population)
# 0         35676000

# %% [markdown]
# To calculate the total value, use the `SUM(column)` function. For example, `SELECT SUM(population) FROM cities` will return the total value in the `population` column.

# %%
# %%sql
#
# SELECT SUM(population)
# FROM cities;
# Out:
#    sum(population)
# 0     1.475535e+09

# %% [markdown]
# To calculate the average value, use the `AVG(column)` function. For example, `SELECT AVG(population) FROM cities` will return the average value in the `population` column.

# %%
# %%sql
#
# SELECT AVG(population) FROM cities;
# Out:
#    avg(population)
# 0     1.181373e+06

# %% [markdown]
# To order the results, use the `ORDER BY column` clause. For example, `SELECT * FROM cities ORDER BY country` will return the rows ordered by the `country` column alphabetically.

# %%
# %%sql
#
# SELECT *
# FROM cities
# ORDER BY country
# LIMIT 10;
# Out:
#      id            name country  latitude  longitude  population
# 0   665           Herat     AFG  34.33001   62.16999      481009
# 1   666  Mazar-e Sharif     AFG  36.69999   67.10003      458151
# 2  1024        Kandahar     AFG  31.61002   65.69495      715542
# 3  1219           Kabul     AFG  34.51669   69.18326     3277000
# 4   669         Malanje     AGO  -9.54000   16.34003      125856
# 5   670        Benguela     AGO -12.57826   13.40723      151226
# 6   671         Lubango     AGO -14.91001   13.49002      125632
# 7  1026        Menongue     AGO -14.66661   17.69999       13030
# 8  1027          Huambo     AGO -12.74999   15.76001     1100000
# 9  1177          Luanda     AGO  -8.83829   13.23443     5172900

# %% [markdown]
# To order the results in descending order, use the `ORDER BY column DESC` clause. For example, `SELECT * FROM cities ORDER BY country ASC, population DESC` will return the rows ordered by the `country` column alphabetical order and then by the `population` column in descending order.

# %%
# %%sql
#
# SELECT *
# FROM cities
# ORDER BY country ASC, population DESC
# LIMIT 10;
# Out:
#      id            name country  latitude  longitude  population
# 0  1219           Kabul     AFG  34.51669   69.18326     3277000
# 1  1024        Kandahar     AFG  31.61002   65.69495      715542
# 2   665           Herat     AFG  34.33001   62.16999      481009
# 3   666  Mazar-e Sharif     AFG  36.69999   67.10003      458151
# 4  1177          Luanda     AGO  -8.83829   13.23443     5172900
# 5  1027          Huambo     AGO -12.74999   15.76001     1100000
# 6   670        Benguela     AGO -12.57826   13.40723      151226
# 7   672          Namibe     AGO -15.19004   12.16002      132900
# 8   669         Malanje     AGO  -9.54000   16.34003      125856
# 9   671         Lubango     AGO -14.91001   13.49002      125632

# %% [markdown]
# ## The WHERE Clause
#
# The `WHERE` clause is used to filter records. The `WHERE` clause is used to extract only those records that fulfill a specified condition.

# %%
# %%sql
#
# SELECT * FROM cities WHERE country='USA'
# Out:
#        id                 name country  latitude  longitude  population
# 0     115                Agana     USA  13.47002  144.75002      122411
# 1     124       San Bernardino     USA  34.12038 -117.30003     1745000
# 2     125           Bridgeport     USA  41.17998  -73.19996     1018000
# 3     126            Rochester     USA  43.17043  -77.61995      755000
# 4     160  International Falls     USA  48.60113  -93.41085       15240
# ..    ...                  ...     ...       ...        ...         ...
# 109  1186              Atlanta     USA  33.83001  -84.39995     4506000
# 110  1187              Chicago     USA  41.82999  -87.75005     8990000
# 111  1223          Los Angeles     USA  33.98998 -118.17998    12500000
# 112  1224      Washington D.C.     USA  38.89955  -77.00942     4338000
# 113  1225             New York     USA  40.74998  -73.98002    19040000
#
# [114 rows x 6 columns]

# %% [markdown]
# You can use boolean operators such as `AND`, `OR`, `NOT` to filter records. For example, `SELECT * FROM cities WHERE country='USA' OR country='CAN'` will return the rows where the `country` column is either `USA` or `CAN`.

# %%
# %%sql
#
# SELECT * FROM cities WHERE country='USA' OR country='CAN';
# Out:
#        id                 name country  latitude  longitude  population
# 0     115                Agana     USA  13.47002  144.75002      122411
# 1     124       San Bernardino     USA  34.12038 -117.30003     1745000
# 2     125           Bridgeport     USA  41.17998  -73.19996     1018000
# 3     126            Rochester     USA  43.17043  -77.61995      755000
# 4     160  International Falls     USA  48.60113  -93.41085       15240
# ..    ...                  ...     ...       ...        ...         ...
# 154  1216            Vancouver     CAN  49.27342 -123.12164     2313328
# 155  1217              Toronto     CAN  43.69998  -79.42002     5213000
# 156  1223          Los Angeles     USA  33.98998 -118.17998    12500000
# 157  1224      Washington D.C.     USA  38.89955  -77.00942     4338000
# 158  1225             New York     USA  40.74998  -73.98002    19040000
#
# [159 rows x 6 columns]

# %% [markdown]
# To select US cities with a population greater than 1 million, use the following query: `SELECT * FROM cities WHERE country='USA' AND population > 1000000`.

# %%
# %%sql
#
# SELECT * FROM cities WHERE country='USA' AND population>1000000;

# %% [markdown]
# To select cities with the country name starting with the letter `U`, use the following query: `SELECT * FROM cities WHERE country LIKE 'U%'`.

# %%
# %%sql
#
# SELECT * FROM cities WHERE country LIKE 'U%';
# Out:
#        id             name country  latitude  longitude  population
# 0       1            Bombo     UGA   0.58330   32.53330       75000
# 1       2      Fort Portal     UGA   0.67100   30.27500       42670
# 2      14            Jinja     UGA   0.44042   33.19993      301619
# 3      15             Arua     UGA   3.02037   30.90002      250000
# 4      16            Mbale     UGA   1.09041   34.17000      402368
# ..    ...              ...     ...       ...        ...         ...
# 134  1189             Kiev     UKR  50.43337   30.51663     2709000
# 135  1191         Tashkent     UZB  41.31170   69.29493     2184000
# 136  1223      Los Angeles     USA  33.98998 -118.17998    12500000
# 137  1224  Washington D.C.     USA  38.89955  -77.00942     4338000
# 138  1225         New York     USA  40.74998  -73.98002    19040000
#
# [139 rows x 6 columns]

# %% [markdown]
# To select cities with the country name ending with the letter `A`, use the following query: `SELECT * FROM cities WHERE country LIKE '%A'`.

# %%
# %%sql
#
# SELECT * FROM cities WHERE country LIKE '%A';
# Out:
#        id            name country  latitude  longitude  population
# 0       1           Bombo     UGA   0.58330   32.53330       75000
# 1       2     Fort Portal     UGA   0.67100   30.27500       42670
# 2       3         Potenza     ITA  40.64200   15.79900       69060
# 3       4      Campobasso     ITA  41.56300   14.65600       50762
# 4       5           Aosta     ITA  45.73700    7.31500       34062
# ..    ...             ...     ...       ...        ...         ...
# 302  1232           Lagos     NGA   6.44326    3.39153     9466000
# 303  1233            Rome     ITA  41.89596   12.48326     3339000
# 304  1242           Paris     FRA  48.86669    2.33334     9904000
# 305  1245  Rio de Janeiro     BRA -22.92502  -43.22502    11748000
# 306  1246       Sao Paulo     BRA -23.55868  -46.62502    18845000
#
# [307 rows x 6 columns]

# %% [markdown]
# To select cities with the country name containing the letter `S` in the middle, use the following query: `SELECT * FROM cities WHERE country LIKE '_S_'`.

# %%
# %%sql
#
# SELECT * FROM cities WHERE country LIKE '_S_';
# Out:
#        id             name country  latitude  longitude  population
# 0       7         Ramallah     PSE  31.90294   35.20621       24599
# 1     113          Palikir     FSM   6.91664  158.14997        4645
# 2     115            Agana     USA  13.47002  144.75002      122411
# 3     124   San Bernardino     USA  34.12038 -117.30003     1745000
# 4     125       Bridgeport     USA  41.17998  -73.19996     1018000
# ..    ...              ...     ...       ...        ...         ...
# 129  1187          Chicago     USA  41.82999  -87.75005     8990000
# 130  1192           Madrid     ESP  40.40003   -3.68335     5567000
# 131  1223      Los Angeles     USA  33.98998 -118.17998    12500000
# 132  1224  Washington D.C.     USA  38.89955  -77.00942     4338000
# 133  1225         New York     USA  40.74998  -73.98002    19040000
#
# [134 rows x 6 columns]

# %% [markdown]
# To select cities from a list of countries, use the `IN` operator. For example, `SELECT * FROM cities WHERE country IN ('USA', 'CAN')` will return the rows where the `country` column is either `USA` or `CAN`.

# %%
# %%sql
#
# SELECT * FROM cities WHERE country IN ('USA', 'CAN');
# Out:
#        id                 name country  latitude  longitude  population
# 0     115                Agana     USA  13.47002  144.75002      122411
# 1     124       San Bernardino     USA  34.12038 -117.30003     1745000
# 2     125           Bridgeport     USA  41.17998  -73.19996     1018000
# 3     126            Rochester     USA  43.17043  -77.61995      755000
# 4     160  International Falls     USA  48.60113  -93.41085       15240
# ..    ...                  ...     ...       ...        ...         ...
# 154  1216            Vancouver     CAN  49.27342 -123.12164     2313328
# 155  1217              Toronto     CAN  43.69998  -79.42002     5213000
# 156  1223          Los Angeles     USA  33.98998 -118.17998    12500000
# 157  1224      Washington D.C.     USA  38.89955  -77.00942     4338000
# 158  1225             New York     USA  40.74998  -73.98002    19040000
#
# [159 rows x 6 columns]

# %% [markdown]
# To select cities with a population between 1 and 10 million, use the following query: `SELECT * FROM cities WHERE population BETWEEN 1000000 AND 10000000`.

# %%
# %%sql
#
# SELECT * FROM cities WHERE population BETWEEN 1000000 AND 10000000;
# Out:
#        id            name country  latitude  longitude  population
# 0      98           Turin     ITA  45.07039    7.66996     1652000
# 1     104           Lille     FRA  50.64997    3.08001     1044000
# 2     124  San Bernardino     USA  34.12038 -117.30003     1745000
# 3     125      Bridgeport     USA  41.17998  -73.19996     1018000
# 4     127      Manchester     GBR  53.50042   -2.24799     2230000
# ..    ...             ...     ...       ...        ...         ...
# 371  1242           Paris     FRA  48.86669    2.33334     9904000
# 372  1243        Santiago     CHL -33.45001  -70.66704     5720000
# 373  1247          Sydney     AUS -33.92001  151.18518     4630000
# 374  1248       Singapore     SGP   1.29303  103.85582     5183700
# 375  1249       Hong Kong     CHN  22.30498  114.18501     7206000
#
# [376 rows x 6 columns]

# %% [markdown]
# ## SQL Joins
#
# Reference: https://www.w3schools.com/sql/sql_join.asp
#
# Here are the different types of the JOINs in SQL:
#
# - `(INNER) JOIN`: Returns records that have matching values in both tables
# - `LEFT (OUTER) JOIN`: Returns all records from the left table, and the matched records from the right table
# - `RIGHT (OUTER) JOIN`: Returns all records from the right table, and the matched records from the left table
# - `FULL (OUTER) JOIN`: Returns all records when there is a match in either left or right table
#
# ![](https://i.imgur.com/mITYzuS.png)
#
# We have two sample tables: `cities` and `countries`.
#
# There are 1,249 cities in the `cities` table and 243 countries in the `countries` table.

# %%
# %%sql
#
# SELECT COUNT(*) FROM cities;
# Out:
#    count_star()
# 0          1249

# %%
# %%sql
#
# SELECT * FROM cities LIMIT 10;
# Out:
#    id              name country  latitude  longitude  population
# 0   1             Bombo     UGA   0.58330   32.53330       75000
# 1   2       Fort Portal     UGA   0.67100   30.27500       42670
# 2   3           Potenza     ITA  40.64200   15.79900       69060
# 3   4        Campobasso     ITA  41.56300   14.65600       50762
# 4   5             Aosta     ITA  45.73700    7.31500       34062
# 5   6         Mariehamn     ALD  60.09700   19.94900       10682
# 6   7          Ramallah     PSE  31.90294   35.20621       24599
# 7   8      Vatican City     VAT  41.90001   12.44781         832
# 8   9           Poitier     FRA  46.58329    0.33328       85960
# 9  10  Clermont-Ferrand     FRA  45.77998    3.08001      233050

# %%
# %%sql
#
# SELECT COUNT(*) FROM countries;
# Out:
#    count_star()
# 0           243

# %%
# %%sql
#
# SELECT * FROM countries LIMIT 10;
# Out:
#    id              Country Alpha2_code Alpha3_code  Numeric_code  Latitude  \
# 0   1          Afghanistan          AF         AFG             4   33.0000
# 1   2              Albania          AL         ALB             8   41.0000
# 2   3              Algeria          DZ         DZA            12   28.0000
# 3   4       American Samoa          AS         ASM            16  -14.3333
# 4   5              Andorra          AD         AND            20   42.5000
# 5   6               Angola          AO         AGO            24  -12.5000
# 6   7             Anguilla          AI         AIA           660   18.2500
# 7   8           Antarctica          AQ         ATA            10  -90.0000
# 8   9  Antigua and Barbuda          AG         ATG            28   17.0500
# 9  10            Argentina          AR         ARG            32  -34.0000
#
#    Longitude
# 0    65.0000
# 1    20.0000
# 2     3.0000
# 3  -170.0000
# 4     1.6000
# 5    18.5000
# 6   -63.1667
# 7     0.0000
# 8   -61.8000
# 9   -64.0000

# %% [markdown]
# ### SQL Inner Join
#
# The `INNER JOIN` keyword selects records that have matching values in both tables. In the example, we join the `cities` table with the `countries` table using the `country` column in the `cities` table and the `Alpha3_code` column in the `countries` table. The result contains 1,244 rows, indicating that there are 5 cities that do not have a matching country.

# %%
# %%sql
#
# SELECT *
# FROM cities
# INNER JOIN countries ON cities.country = countries."Alpha3_code";
# Out:
#         id            name country  latitude  longitude  population  id_1  \
# 0        1           Bombo     UGA   0.58330   32.53330       75000   226
# 1        2     Fort Portal     UGA   0.67100   30.27500       42670   226
# 2        3         Potenza     ITA  40.64200   15.79900       69060   106
# 3        4      Campobasso     ITA  41.56300   14.65600       50762   106
# 4        5           Aosta     ITA  45.73700    7.31500       34062   106
# ...    ...             ...     ...       ...        ...         ...   ...
# 1239  1245  Rio de Janeiro     BRA -22.92502  -43.22502    11748000    30
# 1240  1246       Sao Paulo     BRA -23.55868  -46.62502    18845000    30
# 1241  1247          Sydney     AUS -33.92001  151.18518     4630000    13
# 1242  1248       Singapore     SGP   1.29303  103.85582     5183700   195
# 1243  1249       Hong Kong     CHN  22.30498  114.18501     7206000    43
#
#       Country_1 Alpha2_code Alpha3_code  Numeric_code  Latitude_1  Longitude_1
# 0        Uganda          UG         UGA           800      1.0000      32.0000
# 1        Uganda          UG         UGA           800      1.0000      32.0000
# 2         Italy          IT         ITA           380     42.8333      12.8333
# 3         Italy          IT         ITA           380     42.8333      12.8333
# 4         Italy          IT         ITA           380     42.8333      12.8333
# ...         ...         ...         ...           ...         ...          ...
# 1239     Brazil          BR         BRA            76    -10.0000     -55.0000
# 1240     Brazil          BR         BRA            76    -10.0000     -55.0000
# 1241  Australia          AU         AUS            36    -27.0000     133.0000
# 1242  Singapore          SG         SGP           702      1.3667     103.8000
# 1243      China          CN         CHN           156     35.0000     105.0000
#
# [1244 rows x 13 columns]

# %% [markdown]
# Only select the `city` and `country` columns from the `cities` table and the `Country` column from the `countries` table.

# %%
# %%sql
#
# SELECT name, cities."country", countries."Country" # SELECT THESE COLUMNS
# FROM cities
# INNER JOIN countries ON cities.country = countries."Alpha3_code";
# Out:
#                 name country  Country_1
# 0              Bombo     UGA     Uganda
# 1        Fort Portal     UGA     Uganda
# 2            Potenza     ITA      Italy
# 3         Campobasso     ITA      Italy
# 4              Aosta     ITA      Italy
# ...              ...     ...        ...
# 1239  Rio de Janeiro     BRA     Brazil
# 1240       Sao Paulo     BRA     Brazil
# 1241          Sydney     AUS  Australia
# 1242       Singapore     SGP  Singapore
# 1243       Hong Kong     CHN      China
#
# [1244 rows x 3 columns]

# %% [markdown]
# ### SQL Left Join
#
# The `LEFT JOIN` keyword returns all records from the left table (`cities`), and the matched records from the right table (`countries`). The result contains 1,249 rows, the same number of rows as the `cities` table.

# %%
# %%sql
#
# SELECT *
# FROM cities
# # LEFT JOIN ON CITIES
# LEFT JOIN countries ON cities.country = countries."Alpha3_code"; # RETURNS ALL VALUES
# Out:
#         id         name country  latitude  longitude  population  id_1  \
# 0        1        Bombo     UGA   0.58330   32.53330       75000   226
# 1        2  Fort Portal     UGA   0.67100   30.27500       42670   226
# 2        3      Potenza     ITA  40.64200   15.79900       69060   106
# 3        4   Campobasso     ITA  41.56300   14.65600       50762   106
# 4        5        Aosta     ITA  45.73700    7.31500       34062   106
# ...    ...          ...     ...       ...        ...         ...   ...
# 1244     6    Mariehamn     ALD  60.09700   19.94900       10682  <NA>
# 1245   118   Bir Lehlou     SAH  26.11917   -9.65252         500  <NA>
# 1246   415     Pristina     KOS  42.66671   21.16598      465186  <NA>
# 1247   719      Berbera     SOL  10.43555   45.01641      242344  <NA>
# 1248  1053     Hargeysa     SOL   9.56002   44.06531      477876  <NA>
#
#      Country_1 Alpha2_code Alpha3_code  Numeric_code  Latitude_1  Longitude_1
# 0       Uganda          UG         UGA           800      1.0000      32.0000
# 1       Uganda          UG         UGA           800      1.0000      32.0000
# 2        Italy          IT         ITA           380     42.8333      12.8333
# 3        Italy          IT         ITA           380     42.8333      12.8333
# 4        Italy          IT         ITA           380     42.8333      12.8333
# ...        ...         ...         ...           ...         ...          ...
# 1244      None        None        None          <NA>         NaN          NaN
# 1245      None        None        None          <NA>         NaN          NaN
# 1246      None        None        None          <NA>         NaN          NaN
# 1247      None        None        None          <NA>         NaN          NaN
# 1248      None        None        None          <NA>         NaN          NaN
#
# [1249 rows x 13 columns]

# %% [markdown]
# ### SQL Right Join
#
# The `RIGHT JOIN` keyword returns all records from the right table (`countries`), and the matched records from the left table (`cities`). The result contains 1,291 rows.

# %%
# %%sql
#
# SELECT *
# FROM cities
# RIGHT JOIN countries ON cities.country = countries."Alpha3_code";
# # IN APPEARNCE IT SEEMS THE SAME TABLE BUT THE SUM IS DIFFERENT.
# # BECAUSE COUNTRIES HAS MORE ROWS AND CITY WAS JOINED TO IT
# Out:
#         id         name country  latitude  longitude  population  id_1  \
# 0        1        Bombo     UGA    0.5833    32.5333       75000   226
# 1        2  Fort Portal     UGA    0.6710    30.2750       42670   226
# 2        3      Potenza     ITA   40.6420    15.7990       69060   106
# 3        4   Campobasso     ITA   41.5630    14.6560       50762   106
# 4        5        Aosta     ITA   45.7370     7.3150       34062   106
# ...    ...          ...     ...       ...        ...         ...   ...
# 1286  <NA>         None    None       NaN        NaN        <NA>   224
# 1287  <NA>         None    None       NaN        NaN        <NA>    88
# 1288  <NA>         None    None       NaN        NaN        <NA>   136
# 1289  <NA>         None    None       NaN        NaN        <NA>   139
# 1290  <NA>         None    None       NaN        NaN        <NA>   185
#
#                       Country_1 Alpha2_code Alpha3_code  Numeric_code  \
# 0                        Uganda          UG         UGA           800
# 1                        Uganda          UG         UGA           800
# 2                         Italy          IT         ITA           380
# 3                         Italy          IT         ITA           380
# 4                         Italy          IT         ITA           380
# ...                         ...         ...         ...           ...
# 1286   Turks and Caicos Islands          TC         TCA           796
# 1287                   Guernsey          GG         GGY           831
# 1288                 Martinique          MQ         MTQ           474
# 1289                    Mayotte          YT         MYT           175
# 1290  Saint Pierre and Miquelon          PM         SPM           666
#
#       Latitude_1  Longitude_1
# 0         1.0000      32.0000
# 1         1.0000      32.0000
# 2        42.8333      12.8333
# 3        42.8333      12.8333
# 4        42.8333      12.8333
# ...          ...          ...
# 1286     21.7500     -71.5833
# 1287     49.5000      -2.5600
# 1288     14.6667     -61.0000
# 1289    -12.8333      45.1667
# 1290     46.8333     -56.3333
#
# [1291 rows x 13 columns]

# %% [markdown]
# ### SQL Full Join
#
# The `FULL JOIN` keyword returns all records when there is a match in either left or right table. The result contains 1,296 rows.

# %%
# %%sql
#
# SELECT *
# FROM cities
# FULL JOIN countries ON cities.country = countries."Alpha3_code";
# Out:
#         id         name country  latitude  longitude  population  id_1  \
# 0        1        Bombo     UGA    0.5833    32.5333       75000   226
# 1        2  Fort Portal     UGA    0.6710    30.2750       42670   226
# 2        3      Potenza     ITA   40.6420    15.7990       69060   106
# 3        4   Campobasso     ITA   41.5630    14.6560       50762   106
# 4        5        Aosta     ITA   45.7370     7.3150       34062   106
# ...    ...          ...     ...       ...        ...         ...   ...
# 1291  <NA>         None    None       NaN        NaN        <NA>   224
# 1292  <NA>         None    None       NaN        NaN        <NA>    88
# 1293  <NA>         None    None       NaN        NaN        <NA>   136
# 1294  <NA>         None    None       NaN        NaN        <NA>   139
# 1295  <NA>         None    None       NaN        NaN        <NA>   185
#
#                       Country_1 Alpha2_code Alpha3_code  Numeric_code  \
# 0                        Uganda          UG         UGA           800
# 1                        Uganda          UG         UGA           800
# 2                         Italy          IT         ITA           380
# 3                         Italy          IT         ITA           380
# 4                         Italy          IT         ITA           380
# ...                         ...         ...         ...           ...
# 1291   Turks and Caicos Islands          TC         TCA           796
# 1292                   Guernsey          GG         GGY           831
# 1293                 Martinique          MQ         MTQ           474
# 1294                    Mayotte          YT         MYT           175
# 1295  Saint Pierre and Miquelon          PM         SPM           666
#
#       Latitude_1  Longitude_1
# 0         1.0000      32.0000
# 1         1.0000      32.0000
# 2        42.8333      12.8333
# 3        42.8333      12.8333
# 4        42.8333      12.8333
# ...          ...          ...
# 1291     21.7500     -71.5833
# 1292     49.5000      -2.5600
# 1293     14.6667     -61.0000
# 1294    -12.8333      45.1667
# 1295     46.8333     -56.3333
#
# [1296 rows x 13 columns]

# %% [markdown]
# ### SQL Union
#
# The `UNION` operator is used to combine the result-set of two or more `SELECT` statements.

# %%
# %%sql
#
# SELECT country
# FROM cities
# UNION
# SELECT "Alpha3_code" FROM countries;
# Out:
#     country
# 0       AFG
# 1       ALB
# 2       DZA
# 3       AND
# 4       AGO
# ..      ...
# 242     WLF
# 243     ESH
# 244     YEM
# 245     ZMB
# 246     SOL
#
# [247 rows x 1 columns]

# %% [markdown]
# ## Aggregation
#
# ### Group By
#
# The `GROUP BY` statement groups rows that have the same values into summary rows, like "find the number of cities in each country".
#
# The `GROUP BY` statement is often used with aggregate functions (`COUNT`, `MAX`, `MIN`, `SUM`, `AVG`) to group the result-set by one or more columns.

# %%
# %%sql
# # Take the cities with the same country name from the cities column
# # and group by country and reorder the values by count from highest to lowest
# SELECT COUNT(name), country
# FROM cities
# GROUP BY country
# ORDER BY COUNT(name) DESC;
# Out:
#      count("name") country
# 0              114     USA
# 1              100     CHN
# 2               81     RUS
# 3               69     IND
# 4               46     BRA
# ..             ...     ...
# 195              1     IRL
# 196              1     LBR
# 197              1     CZE
# 198              1     KWT
# 199              1     GHA
#
# [200 rows x 2 columns]

# %%
# %%sql
# # left join contries to city on a unique ID key (3CODE)
# # give me only the country name and group and count total cities
# # reorder
# SELECT countries."Country", COUNT(name)
# FROM cities
# LEFT JOIN countries ON cities.country = countries."Alpha3_code"
# GROUP BY countries."Country"
# ORDER BY COUNT(name) DESC;
#
# # ASK OLLIE: didnt we merge it? how does it know which one to relate to when doing this.
# Out:
#            Country  count("name")
# 0    United States            114
# 1            China            100
# 2           Russia             81
# 3            India             69
# 4           Brazil             46
# ..             ...            ...
# 192     Cape Verde              1
# 193        Hungary              1
# 194        Ireland              1
# 195         Kuwait              1
# 196      Singapore              1
#
# [197 rows x 2 columns]

# %% [markdown]
# ### Having
#
# The `HAVING` clause was added to SQL because the `WHERE` keyword could not be used with aggregate functions.
#
# For example, to select countries with more than 40 cities:

# %%
# %%sql
# # From cities table, select the name column and country column
# # group by country 3 digit code, and count only the name=cities (sum of rows)
# # with more than 40 cities
#
# SELECT COUNT(name), country
# FROM cities
# GROUP BY country
# HAVING COUNT(name) > 40
# ORDER BY COUNT(name) DESC;
# Out:
#    count("name") country
# 0            114     USA
# 1            100     CHN
# 2             81     RUS
# 3             69     IND
# 4             46     BRA
# 5             45     CAN

# %%
# %%sql
# # Work on Cities, left join with countries on the 3 digit code.
# # if countries doesnt have a match with cities return as null.
# # because we want the full names we select the countries name and cities
# # and group by name and only HAVING value above 40 cities
# SELECT countries."Country", COUNT(name)
# FROM cities
# LEFT JOIN countries ON cities.country = countries."Alpha3_code"
# GROUP BY countries."Country"
# HAVING COUNT(name) > 40
# ORDER BY COUNT(name) DESC;
# Out:
#          Country  count("name")
# 0  United States            114
# 1          China            100
# 2         Russia             81
# 3          India             69
# 4         Brazil             46
# 5         Canada             45

# %% [markdown]
# ## Conditional statements
#
# The `CASE` statement goes through conditions and returns a value when the first condition is met (like an `IF-THEN-ELSE` statement). So, once a condition is true, it will stop reading and return the result. If no conditions are true, it returns the value in the `ELSE` clause.
#
# For example, to divide cities into 3 groups based on their population:

# %%
# %%sql
# # Work with cities, select only the name and population column
# # use CASE for conditioning and create a new column
# SELECT name, population,
# CASE
#     WHEN population > 10000000 THEN 'Megacity'
#     WHEN population > 1000000 THEN 'Large city'
#     ELSE 'Small city'
# END AS category
# FROM cities;
# Out:
#                 name  population    category
# 0              Bombo       75000  Small city
# 1        Fort Portal       42670  Small city
# 2            Potenza       69060  Small city
# 3         Campobasso       50762  Small city
# 4              Aosta       34062  Small city
# ...              ...         ...         ...
# 1244  Rio de Janeiro    11748000    Megacity
# 1245       Sao Paulo    18845000    Megacity
# 1246          Sydney     4630000  Large city
# 1247       Singapore     5183700  Large city
# 1248       Hong Kong     7206000  Large city
#
# [1249 rows x 3 columns]

# %% [markdown]
# ## Saving results
#
# You can save the results of a query to a new table using the `CREATE TABLE AS` statement.

# %%
# %%sql
#
# CREATE TABLE cities2 AS SELECT * FROM cities;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Show the new table content.

# %%
# %%sql
#
# FROM cities2;
# Out:
#         id            name country  latitude  longitude  population
# 0        1           Bombo     UGA   0.58330   32.53330       75000
# 1        2     Fort Portal     UGA   0.67100   30.27500       42670
# 2        3         Potenza     ITA  40.64200   15.79900       69060
# 3        4      Campobasso     ITA  41.56300   14.65600       50762
# 4        5           Aosta     ITA  45.73700    7.31500       34062
# ...    ...             ...     ...       ...        ...         ...
# 1244  1245  Rio de Janeiro     BRA -22.92502  -43.22502    11748000
# 1245  1246       Sao Paulo     BRA -23.55868  -46.62502    18845000
# 1246  1247          Sydney     AUS -33.92001  151.18518     4630000
# 1247  1248       Singapore     SGP   1.29303  103.85582     5183700
# 1248  1249       Hong Kong     CHN  22.30498  114.18501     7206000
#
# [1249 rows x 6 columns]

# %% [markdown]
# Use the `DROP TABLE` statement to delete the table.

# %%
# %%sql
#
# DROP TABLE IF EXISTS cities_usa;
# CREATE TABLE cities_usa AS (SELECT * FROM cities WHERE country = 'USA');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
#
# FROM cities_usa;
# Out:
#        id                 name country  latitude  longitude  population
# 0     115                Agana     USA  13.47002  144.75002      122411
# 1     124       San Bernardino     USA  34.12038 -117.30003     1745000
# 2     125           Bridgeport     USA  41.17998  -73.19996     1018000
# 3     126            Rochester     USA  43.17043  -77.61995      755000
# 4     160  International Falls     USA  48.60113  -93.41085       15240
# ..    ...                  ...     ...       ...        ...         ...
# 109  1186              Atlanta     USA  33.83001  -84.39995     4506000
# 110  1187              Chicago     USA  41.82999  -87.75005     8990000
# 111  1223          Los Angeles     USA  33.98998 -118.17998    12500000
# 112  1224      Washington D.C.     USA  38.89955  -77.00942     4338000
# 113  1225             New York     USA  40.74998  -73.98002    19040000
#
# [114 rows x 6 columns]

# %% [markdown]
# Use the `INSERT INTO` statement to insert rows into a table.

# %%
# %%sql
#
# INSERT INTO cities_usa (SELECT * FROM cities WHERE country = 'CAN');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## SQL Comments
#
# Comments are used to explain sections of SQL statements, or to prevent execution of SQL statements.
#
#
# ### Single line comMents
#
# Single line comments start with --.
#
# Any text between -- and the end of the line will be ignored (will not be executed).
#
# The following example uses a single-line comment as an explanation:

# %%
# %%sql
#
# SELECT * FROM cities LIMIT 10 -- This is a comment;
# Out:
#    id              name country  latitude  longitude  population
# 0   1             Bombo     UGA   0.58330   32.53330       75000
# 1   2       Fort Portal     UGA   0.67100   30.27500       42670
# 2   3           Potenza     ITA  40.64200   15.79900       69060
# 3   4        Campobasso     ITA  41.56300   14.65600       50762
# 4   5             Aosta     ITA  45.73700    7.31500       34062
# 5   6         Mariehamn     ALD  60.09700   19.94900       10682
# 6   7          Ramallah     PSE  31.90294   35.20621       24599
# 7   8      Vatican City     VAT  41.90001   12.44781         832
# 8   9           Poitier     FRA  46.58329    0.33328       85960
# 9  10  Clermont-Ferrand     FRA  45.77998    3.08001      233050

# %% [markdown]
# ### Multi-line comments
#
# Multi-line comments start with `/*` and end with `*/`.
#
# Any text between `/*` and `*/` will be ignored.
#
# The following example uses a multi-line comment as an explanation:

# %%
# %%sql
#
# SELECT COUNT(name), country
# FROM cities
# /*
#  * Adding Group by
#  * Adding Order by
#  */
# GROUP BY country
# ORDER BY COUNT(name) DESC
# LIMIT 10;
# Out:
#    count("name") country
# 0            114     USA
# 1            100     CHN
# 2             81     RUS
# 3             69     IND
# 4             46     BRA
# 5             45     CAN
# 6             40     ATA
# 7             36     AUS
# 8             30     FRA
# 9             27     MEX
