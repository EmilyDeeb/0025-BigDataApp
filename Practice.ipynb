# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyDeeb/0025-BSA/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install duckdb leafmap
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.8/662.8 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.4/20.4 MB 50.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 66.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 73.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
# ...

# %%
import duckdb
import leafmap
import pandas as pd

# %%
url = "https://storage.googleapis.com/qm2/CASA0025/nyc_data.db.zip"
leafmap.download_file(url, unzip=True)
# Out:
# Downloading...
# From: https://storage.googleapis.com/qm2/CASA0025/nyc_data.db.zip
# To: /content/nyc_data.db.zip
# 100%|██████████| 8.60M/8.60M [00:00<00:00, 35.0MB/s]
# Extracting files...
# '/content/nyc_data.db.zip'

# %%
con = duckdb.connect('nyc_data.db')
con.install_extension('spatial')
con.load_extension('spatial')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
con.sql("SHOW TABLES;")
# Out:
# ┌─────────────────────┐
# │        name         │
# │       varchar       │
# ├─────────────────────┤
# │ nyc_census_blocks   │
# │ nyc_homicides       │
# │ nyc_neighborhoods   │
# │ nyc_streets         │
# │ nyc_subway_stations │
# └─────────────────────┘

# %%
con.sql("""

""")

# %%
con.sql("""
CREATE TABLE nyc_subway_stations2 AS SELECT * FROM 'https://storage.googleapis.com/qm2/CASA0025/nyc_subway_stations.tsv';
""")
# Just for Extra

# %%
con.sql("""
SELECT BORONAME, NAME
FROM nyc_neighborhoods
LIMIT 10;
""").show()
# Out:
# ┌───────────────┬──────────────────────────┐
# │   BORONAME    │           NAME           │
# │    varchar    │         varchar          │
# ├───────────────┼──────────────────────────┤
# │ Brooklyn      │ Bensonhurst              │
# │ Manhattan     │ East Village             │
# │ Manhattan     │ West Village             │
# │ The Bronx     │ Throggs Neck             │
# │ The Bronx     │ Wakefield-Williamsbridge │
# │ Queens        │ Auburndale               │
# │ Manhattan     │ Battery Park             │
# │ Manhattan     │ Carnegie Hill            │
# │ Staten Island │ Mariners Harbor          │
# │ Staten Island │ Rossville                │
# ├───────────────┴──────────────────────────┤
# │ 10 rows                        2 columns │
# └──────────────────────────────────────────┘

# %%
con.sql("""
SELECT NAME, BOROUGH, ID
FROM nyc_subway_stations
LIMIT 10;
""").show()
# Out:
# ┌──────────────┬───────────┬────────┐
# │     NAME     │  BOROUGH  │   ID   │
# │   varchar    │  varchar  │ double │
# ├──────────────┼───────────┼────────┤
# │ Cortlandt St │ Manhattan │  376.0 │
# │ Rector St    │ Manhattan │    2.0 │
# │ South Ferry  │ Manhattan │    1.0 │
# │ 138th St     │ Bronx     │  125.0 │
# │ 149th St     │ Bronx     │  126.0 │
# │ 149th St     │ Bronx     │   45.0 │
# │ 161st St     │ Bronx     │  127.0 │
# │ 167th St     │ Bronx     │  208.0 │
# │ 167th St     │ Bronx     │  128.0 │
# │ 170th St     │ Bronx     │  209.0 │
# ├──────────────┴───────────┴────────┤
# │ 10 rows                 3 columns │
# └───────────────────────────────────┘

# %%
con.sql("""
SELECT ID NAME, BOROUGH
FROM nyc_sub
""")
